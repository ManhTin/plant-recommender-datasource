# %%
import numpy as np
import pandas as pd

# %%
plants = pd.read_csv('../data/how_many_plants_data.csv', 
                     sep=',',
                     encoding='UTF-8',)

print(plants.columns)
print(plants.origins.unique())
print(plants.climate.unique())
print(plants.water.unique())
print(plants.light.unique())
print(plants.humidity.unique())
print(plants.temperature.unique())
print(plants.toxicity.unique())
# print(plants.size.unique())
print(plants.format.unique())
print(plants.leaf_shape.unique())
print(plants.head(10))
# Out:
# Index(['name', 'official_name', 'alias', 'origins', 'climate', 'description',
#        'difficulty', 'water', 'light', 'humidity', 'temperature', 'toxicity',
#        'size', 'format', 'leaf_shape', 'image_url', 'url'],
#       dtype='object')
# ['Southeast Asia' 'South America' 'Africa & India' 'Central America'
#  'South Africa' 'Central & South America' 'Southeastern Asia' 'India'
#  'Africa' 'Sub-Saharan Africa' 'Southern China' 'West Africa'
#  'Caribbean, Central & South America' 'Eastern & Southern Africa'
#  'Southern Africa' 'India, Malaysia' 'Southeast Asia, French Polynesia'
#  'Southeast Asia & Philippines' 'Eastern Mexico' 'Madagascar'
#  'Australia, Taiwan' 'East & Southeast Asia' 'Eastern Brazil'
#  'Southwest Africa' 'Central & South America, Southeast Asia'
#  'Southeast Arabian Peninsula' 'Northern South America' 'Eastern Europe']
# ['Tropical & Subtropical' 'Tropical' 'Subtropical' 'Tropical (semi-arid)'
# ...

# %%
usda_plants = pd.read_csv('../data/PLANTS.csv',
                            sep=',',
                            encoding='UTF-8',)
print(usda_plants.columns)
print(usda_plants.head(10))
# Out:
# Index(['Accepted Symbol', 'Synonym Symbol', 'Symbol', 'Scientific Name',
#        'Common Name', 'Category', 'Genus', 'Family', 'Family Symbol',
#        'Family Common Name',
#        ...
#        'Fuelwood Product', 'Lumber Product', 'Naval Store Product',
#        'Nursery Stock Product', 'Palatable Browse Animal',
#        'Palatable Graze Animal', 'Palatable Human', 'Post Product',
#        'Protein Potential', 'Pulpwood Product'],
#       dtype='object', length=103)
#   Accepted Symbol Synonym Symbol Symbol               Scientific Name  \
# 0           ABELI            NaN  ABELI                        Abelia
# 1           ABGR4            NaN  ABGR4           Abelia ×grandiflora
# 2           ABELM            NaN  ABELM                   Abelmoschus
# 3            ABES            NaN   ABES        Abelmoschus esculentus
# 4            ABES           HIES   HIES           Hibiscus esculentus
# 5           ABIES            NaN  ABIES                         Abies
# ...
